# %% [markdown]
# A ordem importa da execução do programa

# %%
faturamento = 1000
custo = 500

lucro = faturamento - custo
print(lucro)

custo = 700

lucro = faturamento - custo
print(lucro)
# Out:
# 300
