# %%
faturamento = 2500
custo = 500

lucro = faturamento - custo

print('O faturamento da loja foi ' + str(faturamento))
print('O custo da loja é de ' + str(custo))
print('O lucro da loja foi ' + str(lucro) + ' Reais')
# Out:
# O faturamento da loja foi 2500
# O custo da loja é de 500
# O lucro da loja foi 2000 Reais
